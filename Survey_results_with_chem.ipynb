# %% [markdown]
# ## Chemical Signiture densities
# Visualization of category acerage colored by description. a selection on category that changes the measurements on a barplot below.

# %%
import pandas as pd
import numpy as np
import altair as alt
import ipywidgets as widgets
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

# enable correct rendering
alt.renderers.enable('default')

# uses intermediate json files to speed things up
alt.data_transformers.enable('json')


pd.set_option('display.max_columns', None)

# %%
chem_data = pd.read_csv('assets/chem_data_merged.csv', index_col=0)
survey_data = pd.read_csv('assets/combined_tables.csv', index_col=0)
print('The size of the chem_data dataframe')
print('columns:', chem_data.shape[1])
print('rows   :', chem_data.shape[0])
display(chem_data.sample(5))
print('The size of the survey_data dataframe')
print('columns:', survey_data.shape[1])
print('rows   :', survey_data.shape[0])
survey_data.sample(5)
# Out:
# The size of the chem_data dataframe
# columns: 26
# rows   : 284535
#                  LakeID  LakeStationNo LakeStationType       Lat      Long  \
# 282953       ZACK WOODS              1         Pelagic  44.61106 -72.50256
# 123074             HOWE              1         Pelagic  42.78399 -72.98931
# 83570   FOREST (CALAIS)              1         Pelagic  44.40750 -72.43890
# 42424           CASPIAN              1         Pelagic  44.58897 -72.30878
# 280496       WILLOUGHBY              1         Pelagic  44.74886 -72.06116
#
#               Town ProjectID   VisitDate  VisitNumber  StartTime  \
# 282953   HYDE PARK  SpringTP  2007-05-07            1     1618.0
# 123074   READSBORO  AcidLake  1980-02-20            1      945.0
# 83570       CALAIS    LayMon  2005-06-05            1      800.0
# 42424   GREENSBORO    LayMon  2007-07-21            1     1005.0
# 280496    WESTMORE  SpringTP  2019-05-07            1     1042.0
#
#        CollectionMethodID  Depth ActivityCategory CharacteristicID Symbol  \
# 282953           Hydrolab   1.00              Reg               DO    NaN
# 123074          TygonHose   7.00              Reg               PH    NaN
# 83570                Hose  22.00              Reg             CHLA    NaN
# 42424                Hose  12.00              Reg               TP    NaN
# 280496           Hydrolab  15.04              Reg               PH    NaN
#
#         Result Calcs ProjRemark RemarkCode DepthStratumCode  year  population  \
# 282953    9.97     Y        NaN        NaN              NaN  2007      2883.0
# 123074    5.80     Y        NaN        NaN              NaN  1980         NaN
# 83570     1.83     Y        NaN        NaN              NaN  2005      1578.0
# 42424     8.10     Y        NaN        NaN              NaN  2007       771.0
# 280496    7.70     Y        NaN        NaN              NaN  2019       317.0
#
#        CharacteristicName UnitCode SampleFraction  NormResult
# 282953   Dissolved Oxygen     mg/l            NaN    0.113943
# 123074                 pH     None            NaN    0.312500
# 83570       Chlorophyll-a     ug/l            NaN    0.007087
# 42424    Total Phosphorus     ug/l          Total    0.003530
# 280496                 pH     None            NaN    0.609375
# The size of the survey_data dataframe
# columns: 36
# rows   : 773
#            LakeID           Description       Lat      Long           Town  \
# 690     STOUGHTON       Buffer100ftWBFL  43.37810 -72.50000  WEATHERSFIELD
# 522       NINEVAH             Watershed  43.46890 -72.75330    MOUNT HOLLY
# 264  GREAT HOSMER  Buffer250ftWaterbody  44.68580 -72.36440     CRAFTSBURY
# 518       NICHOLS         Flowline100ft  44.45670 -72.33830       WOODBURY
# 54       BOMOSEEN  Buffer250ftWaterbody  43.64819 -73.21639      CASTLETON
#
#       Shape_Length    Shape_Area  TREE_CANOPY_acres  GRASS_SHRUBS_acres  \
# 690  247471.498256  7.654625e+06        1391.678928          370.430163
# 522   15075.744207  3.643410e+06         817.796160           75.519489
# 264   15719.973425  5.459734e+05         122.189160            9.688122
# 518   32548.794856  1.012339e+06         158.517919           28.643114
# 54    68523.598891  2.564440e+06         391.937132          165.701941
#
#      BARE_SOIL_acres  WATER_acres  BUILDINGS_acres  ROADS_acres  \
# 690         3.627254    99.228719         2.399266    16.702012
# 522         0.225298     1.864407         1.291000     2.528811
# 264         0.047012     1.374583         0.395368     0.631353
# 518         0.610164    62.317348         0.000000     0.041019
# 54          2.380424     7.840209        18.999718    20.952836
#
#      OTHER_PAVED_acres  RAILROADS_acres  Ag_Hay_acres  Ag_Crops_acres  \
# 690           7.218678              0.0    151.723982        0.072109
# 522           1.080220              0.0      3.426502        0.000000
# 264           0.584527              0.0      1.016709        0.000000
# 518           0.000000              0.0      0.392109        0.000000
# 54           25.831801              0.0      7.527129        0.000000
#
#      Ag_Pasture_acres  Ag_Total_acres  Imp_Bare_Soil_acres  \
# 690         20.421005      172.217096             4.125407
# 522          0.000000        3.426502             0.264982
# 264          0.000000        1.016709             0.064564
# 518          0.000000        0.392109             1.014645
# 54           0.000000        7.527129             2.581696
#
#      Imp_Buildings_acres  Imp_Other_Paved_acres  Imp_Road_acres  \
# 690             2.511842               7.997021       28.833995
# 522             1.585524               2.344894        9.579295
# 264             0.473578               0.783853        2.083210
# 518             0.000000               0.000000        0.055089
# 54             21.989564              29.548406       30.287451
#
#      Imp_Railroad_acres  Imp_Total_acres  Shrub_Shrubs_acres  \
# 690                 0.0        43.468265           47.429428
# 522                 0.0        13.774695           41.211828
# 264                 0.0         3.405206            0.000000
# 518                 0.0         1.069735            3.948503
# 54                  0.0        84.407117           11.264529
#
#      Shrub_Total_acres  TC_Coniferous_acres  TC_Deciduous_acres  \
# 690          47.429428           458.688012          935.247023
# 522          41.211828           125.278325          693.086214
# 264           0.000000            83.363074           38.945849
# 518           3.948503            55.527056          103.455637
# 54           11.264529           148.063256          246.704510
#
#      TC_Total_acres  Wet_Emergent_acres  Wet_Forested_acres  \
# 690     1393.935035           98.072321          310.733524
# 522      818.364539           60.566757          100.600091
# 264      122.308923            0.000000            8.497072
# 518      158.982693           15.560348           70.082383
# 54       394.767765           27.761563           38.676271
#
#      Wet_Scrub_Shrub_acres  Wet_Total_acres             from_file  \
# 690              82.795904       491.601749   AOIs_STOUGHTON.xlsx
# 522               6.666105       167.832954     AOIs_NINEVAH.xlsx
# 264               0.111635         8.608707  AOIs_GREATHOSMER.xls
# 518               3.460039        89.102771     AOIs_NICHOLS.xlsx
# 54                6.439068        72.876902     AOIs_BOMOSEEN.xls
#
#      2016_population
# 690           2775.0
# 522           1235.0
# 264           1173.0
# 518            886.0
# 54            4554.0

# %%
# for this visulaization we need the chem_data from 2016 and the LakeID to merge on, the 'CharacteristicID,
# CharacteristicName, UnitCode, and the Result
chem_data_to_merge = chem_data[((chem_data['year'] <= 2016) & (chem_data['year'] >= 2013))].drop('population', axis=1)
chem_data_to_merge = chem_data_to_merge[['LakeID', 'CharacteristicID', 'CharacteristicName', 'Result']].copy()

# Now we Groupby LakeID as we want one measurement: the mean result of each measurement type per lake.
chem_data_to_merge = chem_data_to_merge.groupby(['LakeID', 'CharacteristicID', 'CharacteristicName']).mean().reset_index()
chem_data_to_merge.sample(10)
# Out:
#                 LakeID CharacteristicID CharacteristicName      Result
# 448              CARMI              TFE         Total Iron   97.850000
# 2250            MIRROR               TP   Total Phosphorus   20.523158
# 536            COGGMAN             COND       Conductivity  129.300000
# 3543          STERLING              TCL     Total Chloride    2.000000
# 3405   SPRUCE (ORWELL)              TNA       Total Sodium    1.008667
# 1765     LILY (VERNON)          TURBNTU          Turbidity    1.640000
# 2904              ROOD              TCL     Total Chloride    2.000000
# 2979         RUNNEMEDE               TP   Total Phosphorus   16.904878
# 3823  UNKNOWN (WOODFD)               PH                 pH    5.118000
# 2604  NORTH MONTPELIER              TCA      Total Calcium   33.050000

# %%
# Combine the subcategories in the description
cols_from_survey = ['LakeID', 'Description', 'TREE_CANOPY_acres', 'GRASS_SHRUBS_acres', 'BARE_SOIL_acres', 'WATER_acres', 
                    'BUILDINGS_acres','ROADS_acres', 'OTHER_PAVED_acres', 'RAILROADS_acres', 'Ag_Hay_acres', 
                    'Ag_Crops_acres', 'Ag_Pasture_acres', 'Ag_Total_acres', 'Imp_Bare_Soil_acres', 
                    'Imp_Buildings_acres', 'Imp_Other_Paved_acres', 'Imp_Road_acres', 'Imp_Railroad_acres', 
                    'Imp_Total_acres', 'Shrub_Shrubs_acres', 'Shrub_Total_acres', 'TC_Coniferous_acres', 
                    'TC_Deciduous_acres', 'TC_Total_acres', 'Wet_Emergent_acres', 'Wet_Forested_acres', 
                    'Wet_Scrub_Shrub_acres', 'Wet_Total_acres']
# survey_data_grouped = survey_data[cols_from_survey].groupby('LakeID').sum().reset_index()
survey_data_grouped = survey_data[cols_from_survey]
survey_data_grouped.sample(10)
# Out:
#              LakeID      Description  TREE_CANOPY_acres  GRASS_SHRUBS_acres  \
# 422   LONG (MILTON)        Watershed         262.328027           65.166036
# 545           PARAN  Buffer100ftWBFL         559.258414          269.873687
# 333        HORTONIA   Waterbody100ft          79.183685           22.918062
# 469           MILES   Waterbody100ft          18.831810           12.839699
# 687       STOUGHTON        Watershed       16393.869255         2441.734204
# 663  SOUTH (MARLBR)    Flowline100ft          10.256464            0.528805
# 412   LITTLE HOSMER        Watershed        1132.640671          341.523882
# 207       FAIRFIELD   Waterbody100ft          51.333284           23.216441
# 76          CASPIAN    Flowline100ft         162.241730          102.545857
# 103           COLBY  Buffer100ftWBFL          12.035496            7.291698
#
#      BARE_SOIL_acres  WATER_acres  BUILDINGS_acres  ROADS_acres  \
# 422         0.155305     0.391600         0.680465     3.297307
# 545         0.290719    49.736800         2.127203     7.032855
# 333         0.038301     2.147590         2.218447     0.870922
# 469         0.384186     3.262774         1.709472     0.473947
# 687       110.614453   158.531139        27.970124    78.244130
# 663         0.000000     0.121143         0.000000     0.000000
# 412         4.753250   148.578059         3.877572     6.171262
# 207         0.098224     1.529704         0.854427     1.227988
# 76          0.184958    10.262580         0.236603     2.881121
# 103         0.008896     2.004516         0.000000     0.202873
#
#      OTHER_PAVED_acres  RAILROADS_acres  Ag_Hay_acres  Ag_Crops_acres  \
# 422           2.390061          0.00000     31.841975        0.000000
# 545           7.223188          5.15912     36.756587        0.887914
# 333           1.780392          0.00000      0.598497        0.000000
# 469           2.352131          0.00000      0.000000        0.000000
# 687          75.726933          0.00000   1002.754451       23.959074
# 663           0.000000          0.00000      0.000000        0.000000
# 412           8.164164          0.00000    218.454621       13.435029
# 207           1.606430          0.00000      2.172478        0.000000
# 76            1.129146          0.00000     66.602431        2.488380
# 103           0.169699          0.00000      0.000494        0.000000
#
#      Ag_Pasture_acres  Ag_Total_acres  Imp_Bare_Soil_acres  \
# 422          0.031506       31.873481             0.198916
# 545          7.967762       45.612263             0.324506
# 333          0.000000        0.598497             0.067546
# 469          0.000000        0.000000             0.463646
# 687        236.270996     1262.984521           168.395339
# 663          0.000000        0.000000             0.000000
# 412          0.000000      231.889650             5.790903
# 207          0.000000        2.172478             0.144513
# 76           0.040333       69.131144             0.215957
# 103          5.182611        5.183105             0.028526
#
#      Imp_Buildings_acres  Imp_Other_Paved_acres  Imp_Road_acres  \
# 422             1.078177               2.943753        4.521673
# 545             2.179149               8.061210        7.806462
# 333             3.251562               2.036814        1.255102
# 469             1.880954               2.657219        0.474977
# 687            29.325964              86.272340      145.080746
# 663             0.000000               0.000000        0.000000
# 412             4.075031               9.573499       14.682799
# 207             1.863820               2.069121        1.323912
# 76              0.254642               1.346563        3.374040
# 103             0.000000               0.196570        0.277302
#
#      Imp_Railroad_acres  Imp_Total_acres  Shrub_Shrubs_acres  \
# 422             0.00000         8.742520            5.376287
# 545             5.89077        24.262097           80.298736
# 333             0.00000         6.611024            5.730790
# 469             0.00000         5.476794            0.000000
# 687             0.00000       429.074389          215.055010
# 663             0.00000         0.000000            0.000000
# 412             0.00000        34.122232            7.830162
# 207             0.00000         5.401365            0.000000
# 76              0.00000         5.191202            4.647195
# 103             0.00000         0.502398            0.000000
#
#      Shrub_Total_acres  TC_Coniferous_acres  TC_Deciduous_acres  \
# 422           5.376287           122.739538          140.105573
# 545          80.298736            80.464103          480.633579
# 333           5.730790            36.724933           42.914399
# 469           0.000000             7.084724           11.874139
# 687         215.055010          5131.781440        11276.022678
# 663           0.000000             5.141506            5.128571
# 412           7.830162           598.746971          535.252183
# 207           0.000000            35.072791           16.313781
# 76            4.647195            96.627852           66.359247
# 103           0.000000             7.070392            5.008878
#
#      TC_Total_acres  Wet_Emergent_acres  Wet_Forested_acres  \
# 422      262.845111            7.442352           13.106207
# 545      561.097681          298.917346           65.820872
# 333       79.639332            5.927911            9.812034
# 469       18.958863            2.791294            3.011837
# 687    16407.804119          204.211619         1224.748107
# 663       10.270077            0.379555            4.064424
# 412     1133.999154           27.398367          218.293038
# 207       51.386573           14.445614            7.328076
# 76       162.987099           15.942629           64.874784
# 103       12.079270            1.704532            4.272928
#
#      Wet_Scrub_Shrub_acres  Wet_Total_acres
# 422               0.404019        20.952578
# 545              68.453061       433.191279
# 333               0.657347        16.397292
# 469               0.260898         6.064028
# 687             165.996670      1594.956395
# 663               0.000000         4.443979
# 412              12.110100       257.801505
# 207               0.433541        22.207232
# 76                8.261433        89.078845
# 103               1.136769         7.114228

# %%
merged_data = survey_data_grouped.merge(chem_data_to_merge, how='inner', on='LakeID').drop('LakeID', axis=1)
print(merged_data.shape)
# Out:
# (6950, 31)

# %%
MEASUREMENT_THREASHOLD = 20
corrs = {}
for desc in merged_data['Description'].unique():
    corr_df = pd.DataFrame(index=merged_data.columns[:-3])
    for char in merged_data['CharacteristicID'].unique():
        df = merged_data[((merged_data['CharacteristicID'] == char) & (merged_data['Description'] == desc))]
        # because we are calculating correlations if there are measuremetns with less than 5 measurements
        #  we will drop them as the correlation wont make sense or will be misleading
        if df.shape[0] < MEASUREMENT_THREASHOLD:
            continue
        else:
            df = df.corr()
            df.drop('Result', axis=0, inplace=True)
            df.rename(columns={'Result': char}, inplace=True)
            corr_df[char] = df[char]

    # replace all nan values with 0
    corr_df.fillna(0, inplace=True)
    # drop a column if the entire column is 0
    for col in corr_df.columns:
        if corr_df[col].sum() == 0:
            corr_df.drop(col, axis=1, inplace=True)
    corr_df.drop('Description', axis=0, inplace=True)
    corr_df = corr_df.reset_index().rename(columns={'index': 'survey_type'})
    
    corrs[desc] = corr_df

# %%
for key, cor in corrs.items():
    cor['Description'] = key
    print(key)
    print(cor.shape)
# Out:
# Watershed
# (27, 23)
# Flowline100ft
# (27, 23)
# Waterbody100ft
# (27, 23)
# Buffer100ftWBFL
# (27, 23)
# Buffer250ftWaterbody
# (27, 23)

# %%
corrs_final = pd.concat(corrs, axis=0, ignore_index=True)
print(corrs_final.shape)
# Out:
# (135, 23)

# %%
# melt the data for visualization
corr_df_for_vis = pd.melt(corrs_final, id_vars=['survey_type', 'Description'], var_name='CharacteristicID', value_name='correlation')
# merge CharacteristicName
corr_df_for_vis = corr_df_for_vis.merge(merged_data[['CharacteristicID', 'CharacteristicName']].drop_duplicates(), how='left', on='CharacteristicID')
# lets take the abs value of the corelation column so that we can compare them
# corr_df_for_vis['correlation'] = np.abs(corr_df_for_vis['correlation'])
print(corr_df.shape)
corr_df_for_vis.sample(5)
# Out:
# (27, 23)
#                 survey_type           Description CharacteristicID  \
# 2276           Ag_Hay_acres  Buffer250ftWaterbody              TMG
# 681       OTHER_PAVED_acres             Watershed            TEMPC
# 2498  Imp_Other_Paved_acres        Waterbody100ft               TN
# 1502        Imp_Total_acres             Watershed              TAL
# 1196           Ag_Hay_acres  Buffer250ftWaterbody               DO
#
#       correlation CharacteristicName
# 2276     0.285897    Total Magnesium
# 681     -0.224966        Temperature
# 2498    -0.192482     Total Nitrogen
# 1502     0.175174     Total Aluminum
# 1196     0.240912   Dissolved Oxygen

# %%
options = corr_df_for_vis['Description'].unique()
desc_dropdown = alt.binding_select(options=options, name='Description')
desc_condition = alt.selection_single(fields=['Description'], init={'Description': options[0]}, bind=desc_dropdown)

chart = alt.Chart(corr_df_for_vis).mark_rect().encode(
    x=alt.X('survey_type:N', axis=alt.Axis(title='Land use survey category')),
    y=alt.Y('CharacteristicName:N', axis=alt.Axis(title='Measurement Characteristic')),
    color=alt.condition(alt.datum.correlation == 0, alt.value('white'), alt.Color('correlation:Q')),
    tooltip=[alt.Tooltip('CharacteristicName'), alt.Tooltip('CharacteristicID'), alt.Tooltip('survey_type', title='Survey Type'), alt.Tooltip('correlation')]
).add_selection(
    desc_condition
).transform_filter(
    desc_condition
)
display(chart)
# Out:
# alt.Chart(...)

# %%
# bar chart with health metric
survey = survey_data[cols_from_survey]
health_metric = pd.read_csv('assets/health_metric.csv', index_col=0)
survey = survey.merge(health_metric, how='inner', left_on='LakeID', right_on='Lake').drop('Lake', axis=1)
survey
# Out:
#              LakeID           Description  TREE_CANOPY_acres  \
# 0    BEEBE (HUBDTN)             Watershed        1533.315436
# 1    BEEBE (HUBDTN)         Flowline100ft          87.885117
# 2    BEEBE (HUBDTN)        Waterbody100ft          17.579606
# 3    BEEBE (HUBDTN)       Buffer100ftWBFL         104.498975
# 4    BEEBE (HUBDTN)  Buffer250ftWaterbody          51.140727
# ..              ...                   ...                ...
# 381        WOODWARD             Watershed        1505.119088
# 382        WOODWARD         Flowline100ft         100.124907
# 383        WOODWARD        Waterbody100ft          29.673295
# 384        WOODWARD       Buffer100ftWBFL         129.109027
# 385        WOODWARD  Buffer250ftWaterbody          66.000386
#
#      GRASS_SHRUBS_acres  BARE_SOIL_acres  WATER_acres  BUILDINGS_acres  \
# 0            120.839225         0.728527    62.087602         3.168998
# 1             17.200485         0.090379    21.457054         0.249082
# 2              5.519893         0.000000     0.415013         1.163803
# 3             22.022368         0.090379    21.784221         1.303355
# 4             10.989130         0.002409     0.502797         1.662028
# ..                  ...              ...          ...              ...
# 381           58.863747         0.599539     5.236649         1.440066
# 382            3.815857         0.032865     2.528440         0.097730
# 383            8.879780         0.102363     0.556295         0.160804
# 384           12.155960         0.122379     3.018388         0.244819
# 385           19.103440         0.102363     0.586998         0.383754
#
#      ROADS_acres  OTHER_PAVED_acres  RAILROADS_acres  Ag_Hay_acres  \
# 0       6.108250           5.595013              0.0      6.564360
# 1       0.557654           0.473947              0.0      0.000000
# 2       1.793797           0.802535              0.0      0.000000
# 3       2.322911           1.228235              0.0      0.000000
# 4       2.870557           1.636268              0.0      0.041550
# ..           ...                ...              ...           ...
# 381     5.820929           2.622896              0.0     20.883456
# 382     0.369546           0.173159              0.0      0.395736
# 383     3.008874           0.182549              0.0      0.261202
# 384     3.196489           0.331306              0.0      0.656938
# 385     5.085483           0.726550              0.0      3.485901
#
#      Ag_Crops_acres  Ag_Pasture_acres  Ag_Total_acres  Imp_Bare_Soil_acres  \
# 0               0.0          3.005538        9.569899             0.751036
# 1               0.0          0.000000        0.000000             0.099490
# 2               0.0          0.000000        0.000000             0.000270
# 3               0.0          0.000000        0.000000             0.099490
# 4               0.0          0.000000        0.041550             0.002382
# ..              ...               ...             ...                  ...
# 381             0.0          0.000000       20.883456             0.677340
# 382             0.0          0.000000        0.395736             0.044161
# 383             0.0          0.000000        0.261202             0.121394
# 384             0.0          0.000000        0.656938             0.144936
# 385             0.0          0.000000        3.485901             0.121394
#
#      Imp_Buildings_acres  Imp_Other_Paved_acres  Imp_Road_acres  \
# 0               3.534978               6.223716       12.105696
# 1               0.282718               0.507772        1.204759
# 2               1.335871               0.973365        2.677002
# 3               1.506196               1.432021        3.826569
# 4               1.924462               1.934195        4.792591
# ..                   ...                    ...             ...
# 381             1.546511               2.787029       13.051458
# 382             0.118647               0.175845        0.571775
# 383             0.179635               0.192327        3.367415
# 384             0.276433               0.343567        3.752939
# 385             0.431325               0.771243        6.214525
#
#      Imp_Railroad_acres  Imp_Total_acres  Shrub_Shrubs_acres  \
# 0                   0.0        22.615425           19.418011
# 1                   0.0         2.094738            2.616642
# 2                   0.0         4.986508            0.000000
# 3                   0.0         6.864276            2.616642
# 4                   0.0         8.653630            0.000000
# ..                  ...              ...                 ...
# 381                 0.0        18.062338            3.855110
# 382                 0.0         0.910428            1.804519
# 383                 0.0         3.860771            0.000000
# 384                 0.0         4.517875            1.804519
# 385                 0.0         7.538488            0.000000
#
#      Shrub_Total_acres  TC_Coniferous_acres  TC_Deciduous_acres  \
# 0            19.418011           476.483645         1059.090890
# 1             2.616642            25.718537           62.452233
# 2             0.000000             8.317487            9.372346
# 3             2.616642            33.442268           71.444883
# 4             0.000000            26.456899           24.945123
# ..                 ...                  ...                 ...
# 381           3.855110           195.544654         1310.045364
# 382           1.804519            15.455304           84.699492
# 383           0.000000             9.814316           19.918627
# 384           1.804519            25.105377          104.088503
# 385           0.000000            12.448740           53.730786
#
#      TC_Total_acres  Wet_Emergent_acres  Wet_Forested_acres  \
# 0       1535.574535           22.540547          178.475547
# 1         88.170770           10.418265           30.137750
# 2         17.689833            0.325501            2.166806
# 3        104.887150           10.507340           32.000307
# 4         51.402022            1.000211            4.420883
# ..              ...                 ...                 ...
# 381     1505.590018            0.921516           43.764494
# 382      100.154796            0.000000            3.786434
# 383       29.732943            0.042003            0.815254
# 384      129.193880            0.042003            4.577352
# 385       66.179525            0.255969            1.525622
#
#      Wet_Scrub_Shrub_acres  Wet_Total_acres  Health_Score
# 0                 2.164772       203.180867      1.017794
# 1                 0.385794        40.941809      1.017794
# 2                 0.000000         2.492307      1.017794
# 3                 0.385794        42.893441      1.017794
# 4                 0.000000         5.421094      1.017794
# ..                     ...              ...           ...
# 381               4.610979        49.296989      1.315273
# 382               1.762558         5.548992      1.315273
# 383               0.000000         0.857257      1.315273
# 384               1.762558         6.381914      1.315273
# 385               0.000000         1.781591      1.315273
#
# [386 rows x 30 columns]

# %%
results_df = pd.DataFrame(index=survey.columns[2 : -1])
for desc in survey['Description'].unique():
    df = survey[survey['Description'] == desc]
    corr_df = df.corr()
    corr_df.drop('Health_Score', axis=0, inplace=True)
    results_df[desc] = corr_df['Health_Score']
results_df = results_df.reset_index().rename(columns={'index': 'survey_type'})
results_df = pd.melt(results_df, id_vars='survey_type', var_name='Description', value_name='correlation')
results_df
# Out:
#                survey_type           Description  correlation
# 0        TREE_CANOPY_acres             Watershed    -0.035824
# 1       GRASS_SHRUBS_acres             Watershed     0.067897
# 2          BARE_SOIL_acres             Watershed     0.061495
# 3              WATER_acres             Watershed     0.038861
# 4          BUILDINGS_acres             Watershed     0.130100
# ..                     ...                   ...          ...
# 130         TC_Total_acres  Buffer250ftWaterbody    -0.035261
# 131     Wet_Emergent_acres  Buffer250ftWaterbody     0.381516
# 132     Wet_Forested_acres  Buffer250ftWaterbody    -0.038068
# 133  Wet_Scrub_Shrub_acres  Buffer250ftWaterbody     0.086818
# 134        Wet_Total_acres  Buffer250ftWaterbody     0.162405
#
# [135 rows x 3 columns]

# %%
# options = results_df['Description'].unique()
# desc_dropdown = alt.binding_select(options=options, name='Description')
# desc_condition = alt.selection_single(fields=['Description'], init={'Description': options[0]}, bind=desc_dropdown)

alt.Chart(results_df).mark_bar().encode(
    x=alt.X('correlation:Q'),
    y=alt.Y('survey_type', sort='-x')
).add_selection(
    desc_condition
).transform_filter(
    desc_condition
)
# Out:
# alt.Chart(...)
