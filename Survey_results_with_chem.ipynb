# %% [markdown]
# ## Chemical Measurements and Land Use
# Visualizations here deal with the land use survey and the interaction/correlation with the chemical measurements data
# ### Section 1: Data

# %%
import pandas as pd
import numpy as np
import altair as alt
import IPython
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

alt.renderers.enable('default')
alt.data_transformers.enable('json')

# show Max Rows
pd.set_option('display.max_columns', None)

# %%
# import the data
chem_data = pd.read_csv('assets/chem_data_merged.csv', index_col=0)
survey_data = pd.read_csv('assets/combined_tables.csv', index_col=0)
health_metric = pd.read_csv('assets/health_metric.csv', index_col=0)
print('The size of the chem_data dataframe')
print('columns:', chem_data.shape[1])
print('rows   :', chem_data.shape[0])
display(chem_data.sample(5))
print('The size of the survey_data dataframe')
print('columns:', survey_data.shape[1])
print('rows   :', survey_data.shape[0])
display(survey_data.sample(5))
print('The size of the health_metric dataframe')
print('columns:', health_metric.shape[1])
print('rows   :', health_metric.shape[0])
display(health_metric.sample(5))
# Out:
# The size of the chem_data dataframe
# columns: 26
# rows   : 284535
#           LakeID  LakeStationNo LakeStationType       Lat      Long  \
# 164301   METCALF              1         Pelagic  44.72883 -72.88330
# 200832      ROOD              1         Pelagic  44.07672 -72.58721
# 131455    ISLAND              1         Pelagic  44.80750 -71.87330
# 55777   CRESCENT              1         Pelagic  43.80250 -72.40830
# 239841  STAMFORD              1         Pelagic  42.82220 -73.06560
#
#                 Town ProjectID   VisitDate  VisitNumber  StartTime  \
# 164301      FLETCHER    Laymon  1981-08-18            1     1745.0
# 200832  WILLIAMSTOWN  SpringTP  1998-04-28            1      953.0
# 131455      BRIGHTON    Laymon  2013-06-01            1     1000.0
# 55777         SHARON  SpringTP  2003-05-06            1        NaN
# 239841      STAMFORD  AcidLake  2012-04-04            1      918.0
#
#        CollectionMethodID  Depth ActivityCategory CharacteristicID Symbol  \
# 164301             Secchi    NaN              Reg           SECCHI    NaN
# 200832           Hydrolab   15.5              Reg               PH    NaN
# 131455             Secchi    NaN              Reg           SECCHI    NaN
# 55777            Kemmerer    1.0              Reg           REGALK    NaN
# 239841        PlasticKemm    1.0              Reg               PH    NaN
#
#         Result Calcs ProjRemark RemarkCode DepthStratumCode  year  population  \
# 164301    3.00     Y        NaN        NaN              NaN  1981         NaN
# 200832    7.24     Y        NaN        NaN              NaN  1998      3153.0
# 131455    2.50     Y        NaN        NaN              NaN  2013      1202.0
# 55777    60.90     Y        NaN          J              NaN  2003      1454.0
# 239841    5.67     Y        NaN        NaN              NaN  2012       818.0
#
#          CharacteristicName UnitCode SampleFraction  NormResult
# 164301  Secchi transparency        m            NaN    0.189360
# 200832                   pH     None            NaN    0.537500
# 131455  Secchi transparency        m            NaN    0.157695
# 55777            Alkalinity     mg/l            NaN    0.323576
# 239841                   pH     None            NaN    0.292187
# The size of the survey_data dataframe
# columns: 35
# rows   : 773
#             LakeID           Description       Lat      Long           Town  \
# 446         LYFORD  Buffer250ftWaterbody  44.44499 -72.25037         WALDEN
# 430  LONG (WESTMR)       Buffer100ftWBFL  44.75274 -72.01827       WESTMORE
# 497          MOREY             Watershed  43.92470 -72.15330        FAIRLEE
# 690      STOUGHTON       Buffer100ftWBFL  43.37810 -72.50000  WEATHERSFIELD
# 162  ECHO (CHARTN)        Waterbody100ft  44.86231 -71.99507     CHARLESTON
#
#       Shape_Length    Shape_Area  TREE_CANOPY_acres  GRASS_SHRUBS_acres  \
# 446    5049.037711  1.780350e+05          25.966226           14.772987
# 430   11082.692468  2.196202e+05          44.030404            6.078845
# 497   29184.038434  1.611138e+07        3666.238383          258.456077
# 690  247471.498256  7.654625e+06        1391.678928          370.430163
# 162   13820.829492  2.089678e+05          28.747763           15.769562
#
#      BARE_SOIL_acres  WATER_acres  BUILDINGS_acres  ROADS_acres  \
# 446         0.146039     0.739894         0.842443     0.768188
# 430         0.083027     3.568752         0.285097     0.054610
# 497         1.239540     6.284621         7.044840    26.466552
# 690         3.627254    99.228719         2.399266    16.702012
# 162         0.279105     1.881705         1.414305     1.763527
#
#      OTHER_PAVED_acres  RAILROADS_acres  Ag_Hay_acres  Ag_Crops_acres  \
# 446           0.752867              0.0      4.270728        0.000000
# 430           0.158950              0.0      0.000000        0.000000
# 497          15.476310              0.0     24.816965        0.000000
# 690           7.218678              0.0    151.723982        0.072109
# 162           1.773225              0.0      2.424662        0.000000
#
#      Ag_Pasture_acres  Ag_Total_acres  Imp_Bare_Soil_acres  \
# 446          0.000000        4.270728             0.143128
# 430          0.000000        0.000000             0.095084
# 497          0.000000       24.816965             1.448227
# 690         20.421005      172.217096             4.125407
# 162          0.000000        2.424662             0.322078
#
#      Imp_Buildings_acres  Imp_Other_Paved_acres  Imp_Road_acres  \
# 446             0.922725               0.803939        1.457908
# 430             0.311064               0.174565        0.250100
# 497             8.327905              17.109996       38.801259
# 690             2.511842               7.997021       28.833995
# 162             1.520160               2.056316        2.132835
#
#      Imp_Railroad_acres  Imp_Total_acres  Shrub_Shrubs_acres  \
# 446                 0.0         3.327700            1.363696
# 430                 0.0         0.830813            0.000000
# 497                 0.0        65.687387           22.864266
# 690                 0.0        43.468265           47.429428
# 162                 0.0         6.031389            0.000000
#
#      Shrub_Total_acres  TC_Coniferous_acres  TC_Deciduous_acres  \
# 446           1.363696            17.083150            8.997516
# 430           0.000000            26.960429           17.142511
# 497          22.864266          1445.031792         2223.468782
# 690          47.429428           458.688012          935.247023
# 162           0.000000            15.120139           13.784907
#
#      TC_Total_acres  Wet_Emergent_acres  Wet_Forested_acres  \
# 446       26.080667            1.689867            9.961012
# 430       44.102941            1.535361            6.712663
# 497     3668.500574           19.231006           94.247493
# 690     1393.935035           98.072321          310.733524
# 162       28.905046            1.676447           11.551497
#
#      Wet_Scrub_Shrub_acres  Wet_Total_acres            from_file
# 446               1.442460        13.093339      AOIs_LYFORD.xls
# 430               2.559917        10.807941  AOIs_LONGWESTMR.xls
# 497              18.853389       132.331888       AOIs_MOREY.xls
# 690              82.795904       491.601749  AOIs_STOUGHTON.xlsx
# 162               0.265099        13.493043  AOIs_ECHOCHARTN.xls
# The size of the health_metric dataframe
# columns: 2
# rows   : 90
#                 Lake  Health_Score
# 47             MILES      1.840927
# 14           SEYMOUR      1.839372
# 11         GREENWOOD      1.076986
# 85           DUNMORE      0.089848
# 59  CRYSTAL (BARTON)      2.013260

# %% [markdown]
# ### Section 2: Merging the Data for Heatmap Visulaization

# %%
# for this visulaization we need the chem_data from 2013 - 2016 and the LakeID to merge on, the 'CharacteristicID,
# CharacteristicName, and the Result
chem_data_to_merge = chem_data[((chem_data['year'] <= 2016) & (chem_data['year'] >= 2013))]
chem_data_to_merge = chem_data_to_merge[['LakeID', 'CharacteristicID', 'CharacteristicName', 'Result']].copy()

# Now we Groupby LakeID as we want one measurement: the mean result of each measurement type per lake.
chem_data_to_merge = chem_data_to_merge.groupby(['LakeID', 'CharacteristicID', 'CharacteristicName']).mean().reset_index()
chem_data_to_merge.sample(10)
# Out:
#                     LakeID CharacteristicID  \
# 3620          SUGAR HOLLOW           SECCHI
# 3580              STRATTON          GRANALK
# 1024               GILLETT             CHLA
# 2976             RUNNEMEDE               TN
# 2148       LOWER WINOOSKI;          TURBNTU
# 358                  BROWN              TAL
# 422          BURR (PITTFD)           SECCHI
# 1602  KETTLE (BRATTLEBORO)              TNA
# 2738                 PECKS          TURBNTU
# 2927        ROUND (HOLLND)               TP
#
#                              CharacteristicName      Result
# 3620                        Secchi transparency    1.100000
# 3580  Alkalinity measured using Gran Alkalinity    1.743333
# 1024                              Chlorophyll-a    3.430000
# 2976                             Total Nitrogen    0.210000
# 2148                                  Turbidity   23.875000
# 358                              Total Aluminum   50.000000
# 422                         Secchi transparency    5.000000
# 1602                               Total Sodium  119.800000
# 2738                                  Turbidity    0.000000
# 2927                           Total Phosphorus   11.955000

# %%
# Combine the subcategories in the description
cols_from_survey = ['LakeID', 'Description', 'TREE_CANOPY_acres', 'GRASS_SHRUBS_acres', 'BARE_SOIL_acres', 'WATER_acres', 
                    'BUILDINGS_acres','ROADS_acres', 'OTHER_PAVED_acres', 'RAILROADS_acres', 'Ag_Hay_acres', 
                    'Ag_Crops_acres', 'Ag_Pasture_acres', 'Ag_Total_acres', 'Imp_Bare_Soil_acres', 
                    'Imp_Buildings_acres', 'Imp_Other_Paved_acres', 'Imp_Road_acres', 'Imp_Railroad_acres', 
                    'Imp_Total_acres', 'Shrub_Shrubs_acres', 'Shrub_Total_acres', 'TC_Coniferous_acres', 
                    'TC_Deciduous_acres', 'TC_Total_acres', 'Wet_Emergent_acres', 'Wet_Forested_acres', 
                    'Wet_Scrub_Shrub_acres', 'Wet_Total_acres']
# survey_data_grouped = survey_data[cols_from_survey].groupby('LakeID').sum().reset_index()
survey_data_grouped = survey_data[cols_from_survey]
survey_data_grouped.sample(10)
# Out:
#              LakeID           Description  TREE_CANOPY_acres  \
# 321         HOLLAND             Watershed        4173.599805
# 13          AMHERST       Buffer100ftWBFL         933.931124
# 38              BIG       Buffer100ftWBFL          43.447793
# 17           ATHENS        Waterbody100ft           7.496857
# 530          NORTON       Buffer100ftWBFL        1320.619252
# 163   ECHO (CHARTN)       Buffer100ftWBFL         504.675700
# 7    ADAMS (WOODFD)        Waterbody100ft          15.775060
# 748          WINONA             Watershed        1833.367810
# 691       STOUGHTON  Buffer250ftWaterbody          35.793901
# 583          RESCUE         Flowline100ft        1565.557079
#
#      GRASS_SHRUBS_acres  BARE_SOIL_acres  WATER_acres  BUILDINGS_acres  \
# 321          225.055388         1.868237   107.125577         1.209826
# 13           108.734354         2.579467    48.460503         1.008991
# 38             5.801346         0.000000     0.683184         1.030860
# 17             1.891342         0.017977     0.440218         0.000000
# 530           93.230987         1.561271    44.281463         0.656929
# 163          158.021485         0.860420   177.818550         2.486309
# 7              0.583353         0.029158     1.074907         0.000000
# 748         1239.345985         5.494318    23.828768         7.041072
# 691            6.899048         0.187120     0.576496         0.023351
# 583          172.970349         3.083623   153.455047         1.785828
#
#      ROADS_acres  OTHER_PAVED_acres  RAILROADS_acres  Ag_Hay_acres  \
# 321     4.315380           3.010604            0.000     26.556409
# 13     10.993207           4.160322            0.000      4.370632
# 38      0.520774           1.521611            0.000      0.000000
# 17      0.144062           0.072278            0.000      0.000000
# 530     4.342685           2.816070            3.953      0.000000
# 163     5.871400           6.050119            0.000     67.961500
# 7       0.000000           0.042996            0.000      0.000000
# 748    10.596295          23.540211            0.000    198.802080
# 691     0.510210           0.314812            0.000      0.006160
# 583    15.340217           6.463711            0.000      7.064728
#
#      Ag_Crops_acres  Ag_Pasture_acres  Ag_Total_acres  Imp_Bare_Soil_acres  \
# 321        0.000000          0.000000       26.556409             2.125118
# 13         0.000000          1.431078        5.801711             3.184252
# 38         0.000000          0.000000        0.000000             0.000000
# 17         0.000000          0.000000        0.000000             0.017234
# 530        0.000000          0.000000        0.000000             1.906303
# 163        0.000000          0.000000       67.961500             1.033193
# 7          0.000000          0.000000        0.000000             0.057980
# 748      388.739568          4.643474      592.185122             5.652009
# 691        0.000000          0.000000        0.006160             0.192712
# 583        0.448112          6.403616       13.916455             3.740297
#
#      Imp_Buildings_acres  Imp_Other_Paved_acres  Imp_Road_acres  \
# 321             1.328209               3.699084        7.298394
# 13              1.096061               4.650435       16.147106
# 38              1.065426               1.759635        0.570527
# 17              0.000000               0.071809        0.561686
# 530             0.853834               3.460954        6.387541
# 163             2.638996               6.653821        7.430658
# 7               0.000000               0.163275        0.000000
# 748             7.332573              24.322106       15.359321
# 691             0.023680               0.316790        0.715795
# 583             1.935613               7.183300       28.265200
#
#      Imp_Railroad_acres  Imp_Total_acres  Shrub_Shrubs_acres  \
# 321            0.000000        14.450805           49.533898
# 13             0.000000        25.077854           37.126099
# 38             0.000000         3.395588            0.000000
# 17             0.000000         0.650729            0.000000
# 530            4.263762        16.872395            6.290469
# 163            0.000000        17.756668           10.357996
# 7              0.000000         0.221256            0.000000
# 748            0.000000        52.666009          510.011264
# 691            0.000000         1.248977            3.848891
# 583            0.000000        41.124409           39.652373
#
#      Shrub_Total_acres  TC_Coniferous_acres  TC_Deciduous_acres  \
# 321          49.533898          1586.558591         2589.134115
# 13           37.126099           165.607611          769.279091
# 38            0.000000            13.823144           29.688281
# 17            0.000000             3.973165            3.540990
# 530           6.290469           349.068474          972.989197
# 163          10.357996           215.532652          290.231170
# 7             0.000000             7.591926            8.177718
# 748         510.011264           430.463379         1403.866829
# 691           3.848891            29.489583            6.345927
# 583          39.652373           298.858161         1268.233735
#
#      TC_Total_acres  Wet_Emergent_acres  Wet_Forested_acres  \
# 321     4175.692706          136.683387         1146.262926
# 13       934.886702           56.426981          241.015514
# 38        43.511425            0.000000            6.426550
# 17         7.514155            1.217739            0.831646
# 530     1322.057671           72.790009          282.687835
# 163      505.763822           49.947719          166.579700
# 7         15.769644            0.000000            2.195926
# 748     1834.330207          511.983282          140.670321
# 691       35.835510            1.280229            2.067088
# 583     1567.091896           81.702966          368.274013
#
#      Wet_Scrub_Shrub_acres  Wet_Total_acres
# 321              45.153158      1328.099471
# 13               49.503565       346.946061
# 38                0.000000         6.426550
# 17                0.311238         2.360624
# 530              23.263467       378.741311
# 163              27.376920       243.904339
# 7                 0.000000         2.195926
# 748              33.952064       686.605667
# 691               3.556576         6.903893
# 583              66.028919       516.005898

# %%
merged_data = survey_data_grouped.merge(chem_data_to_merge, how='inner', on='LakeID').drop('LakeID', axis=1)
print(merged_data.shape)
# Out:
# (6950, 31)

# %% [markdown]
# ### Section 3: Calculating the Correlations for Heatmap Visulaization

# %%
MEASUREMENT_THREASHOLD = 20
corrs = {}
for desc in merged_data['Description'].unique():
    corr_df = pd.DataFrame(index=merged_data.columns[:-3])
    for char in merged_data['CharacteristicID'].unique():
        df = merged_data[((merged_data['CharacteristicID'] == char) & (merged_data['Description'] == desc))]
        # because we are calculating correlations if there are measuremetns with less than 5 measurements
        #  we will drop them as the correlation wont make sense or will be misleading
        if df.shape[0] < MEASUREMENT_THREASHOLD:
            continue
        else:
            df = df.corr()
            df.drop('Result', axis=0, inplace=True)
            df.rename(columns={'Result': char}, inplace=True)
            corr_df[char] = df[char]

    # replace all nan values with 0
    corr_df.fillna(0, inplace=True)
    # drop a column if the entire column is 0
    for col in corr_df.columns:
        if corr_df[col].sum() == 0:
            corr_df.drop(col, axis=1, inplace=True)
    corr_df.drop('Description', axis=0, inplace=True)
    corr_df = corr_df.reset_index().rename(columns={'index': 'survey_type'})
    
    corrs[desc] = corr_df

# %%
for key, cor in corrs.items():
    cor['Description'] = key
    print(key)
    print(cor.shape)
# Out:
# Watershed
# (27, 23)
# Flowline100ft
# (27, 23)
# Waterbody100ft
# (27, 23)
# Buffer100ftWBFL
# (27, 23)
# Buffer250ftWaterbody
# (27, 23)

# %%
corrs_final = pd.concat(corrs, axis=0, ignore_index=True)
print(corrs_final.shape)
# Out:
# (135, 23)

# %%
# melt the data for visualization
corr_df_for_vis = pd.melt(corrs_final, id_vars=['survey_type', 'Description'], var_name='CharacteristicID', value_name='correlation')
# merge CharacteristicName
corr_df_for_vis = corr_df_for_vis.merge(merged_data[['CharacteristicID', 'CharacteristicName']].drop_duplicates(), how='left', on='CharacteristicID')
# lets take the abs value of the corelation column so that we can compare them
# corr_df_for_vis['correlation'] = np.abs(corr_df_for_vis['correlation'])
print(corr_df.shape)
corr_df_for_vis.sample(5)
# Out:
# (27, 23)
#               survey_type    Description CharacteristicID  correlation  \
# 2190          WATER_acres  Flowline100ft              TMG    -0.113697
# 2432      BARE_SOIL_acres      Watershed               TN    -0.066490
# 1655         Ag_Hay_acres  Flowline100ft              TCA     0.055866
# 975           WATER_acres  Flowline100ft        CHLAPROBE    -0.145619
# 579   Imp_Bare_Soil_acres  Flowline100ft               PH    -0.150901
#
#          CharacteristicName
# 2190        Total Magnesium
# 2432         Total Nitrogen
# 1655          Total Calcium
# 975   Chlorophyll-a (probe)
# 579                      pH

# %% [markdown]
# ### Section 4: Heatmap Visualization

# %%
options = corr_df_for_vis['Description'].unique()
desc_dropdown = alt.binding_select(options=options, name='Description ')
desc_condition = alt.selection_single(fields=['Description'], init={'Description': options[0]}, bind=desc_dropdown)

chart = alt.Chart(corr_df_for_vis).mark_rect().encode(
    x=alt.X('survey_type:N', axis=alt.Axis(title=None)),
    y=alt.Y('CharacteristicName:N', axis=alt.Axis(title=None)),
    color=alt.condition(alt.datum.correlation == 0, alt.value('white'), alt.Color('correlation:Q')),
    tooltip=[alt.Tooltip('CharacteristicName'), alt.Tooltip('CharacteristicID'), alt.Tooltip('survey_type', title='Survey Type'), alt.Tooltip('correlation')]
).add_selection(
    desc_condition
).transform_filter(
    desc_condition
).properties(
    title=alt.TitleParams('Correlation heatmap of chemical measurements and Land use')
)
display(chart)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Section 5: Merging the Data and calculating the correlations for Health Metric Bar chart

# %%
# bar chart with health metric
survey = survey_data[cols_from_survey]
survey = survey.merge(health_metric, how='inner', left_on='LakeID', right_on='Lake').drop('Lake', axis=1)

# %%
results_df = pd.DataFrame(index=survey.columns[2 : -1])
for desc in survey['Description'].unique():
    df = survey[survey['Description'] == desc]
    corr_df = df.corr()
    corr_df.drop('Health_Score', axis=0, inplace=True)
    results_df[desc] = corr_df['Health_Score']
results_df = results_df.reset_index().rename(columns={'index': 'survey_type'})
results_df = pd.melt(results_df, id_vars='survey_type', var_name='Description', value_name='correlation')
results_df
# Out:
#                survey_type           Description  correlation
# 0        TREE_CANOPY_acres             Watershed    -0.035824
# 1       GRASS_SHRUBS_acres             Watershed     0.067897
# 2          BARE_SOIL_acres             Watershed     0.061495
# 3              WATER_acres             Watershed     0.038861
# 4          BUILDINGS_acres             Watershed     0.130100
# ..                     ...                   ...          ...
# 130         TC_Total_acres  Buffer250ftWaterbody    -0.035261
# 131     Wet_Emergent_acres  Buffer250ftWaterbody     0.381516
# 132     Wet_Forested_acres  Buffer250ftWaterbody    -0.038068
# 133  Wet_Scrub_Shrub_acres  Buffer250ftWaterbody     0.086818
# 134        Wet_Total_acres  Buffer250ftWaterbody     0.162405
#
# [135 rows x 3 columns]

# %% [markdown]
# ### Section 6: Health metric and land use survey bar chart

# %%
alt.Chart(results_df).mark_bar().encode(
    x=alt.X('correlation:Q'),
    y=alt.Y('survey_type', sort='-x')
).add_selection(
    desc_condition
).transform_filter(
    desc_condition
).properties(
    title=alt.TitleParams('Survey categories correlated with the derived Health Meric')
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Documentation

# %%
# %load_ext watermark
# %watermark --iversions
# Out:
# altair : 4.1.0
# sys    : 3.9.9 | packaged by conda-forge | (main, Dec 20 2021, 02:36:06) [MSC v.1929 64 bit (AMD64)]
# IPython: 7.29.0
# numpy  : 1.21.5
# pandas : 1.3.4
