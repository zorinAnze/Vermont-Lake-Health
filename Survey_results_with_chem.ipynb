# %% [markdown]
# ## Chemical Measurements and Land Use
# Visualizations here deal with the land use survey and the interaction/correlation with the chemical measurements data
# ### Section 1: Data

# %%
import pandas as pd
import numpy as np
import altair as alt
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

alt.renderers.enable('default')
alt.data_transformers.enable('json')

# show Max Rows
pd.set_option('display.max_columns', None)

# %%
# import the data
chem_data = pd.read_csv('assets/chem_data_merged.csv', index_col=0)
survey_data = pd.read_csv('assets/combined_tables.csv', index_col=0)
health_metric = pd.read_csv('assets/health_metric.csv', index_col=0)
print('The size of the chem_data dataframe')
print('columns:', chem_data.shape[1])
print('rows   :', chem_data.shape[0])
display(chem_data.sample(5))
print('The size of the survey_data dataframe')
print('columns:', survey_data.shape[1])
print('rows   :', survey_data.shape[0])
display(survey_data.sample(5))
print('The size of the health_metric dataframe')
print('columns:', health_metric.shape[1])
print('rows   :', health_metric.shape[0])
display(health_metric.sample(5))
# Out:
# The size of the chem_data dataframe
# columns: 26
# rows   : 284535
#                  LakeID  LakeStationNo LakeStationType       Lat      Long  \
# 171072            MOREY              1         Pelagic  43.92470 -72.15330
# 141330  LITTLE (WINHLL)              1         Pelagic  43.12360 -72.94280
# 153401    LONG (WESTMR)              1         Pelagic  44.75274 -72.01827
# 65645         EAST LONG              1         Pelagic  44.44750 -72.35250
# 64707           DUNMORE              1         Pelagic  43.91220 -73.07640
#
#              Town ProjectID   VisitDate  VisitNumber  StartTime  \
# 171072    FAIRLEE    Laymon  1991-06-24            1     1405.0
# 141330    WINHALL  AcidLake  1983-08-31            1      940.0
# 153401   WESTMORE  SpringTP  2010-04-19            1     1118.0
# 65645    WOODBURY  SpringTP  1998-05-01            1     1300.0
# 64707   SALISBURY  LaymonQC  2018-08-14            1     1056.0
#
#        CollectionMethodID  Depth ActivityCategory CharacteristicID Symbol  \
# 171072             Secchi    NaN              Reg           SECCHI    NaN
# 141330          TygonHose   1.00              Reg               TK    NaN
# 153401           Hydrolab  20.00              Reg               DO    NaN
# 65645            Hydrolab  26.70              Reg              DO%    NaN
# 64707            Hydrolab   5.86              Reg               DO    NaN
#
#         Result Calcs ProjRemark RemarkCode DepthStratumCode  year  population  \
# 171072    7.00     Y        NaN        NaN              NaN  1991       891.0
# 141330    0.44     Y        NaN        NaN              NaN  1983         NaN
# 153401   10.87     Y        NaN        NaN              NaN  2010       350.0
# 65645    46.80     Y        NaN        NaN              NaN  1998       801.0
# 64707     7.99     Y        NaN        NaN              NaN  2018      1117.0
#
#                  CharacteristicName UnitCode SampleFraction  NormResult
# 171072          Secchi transparency        m            NaN    0.442685
# 141330              Total Potassium     mg/l          Total    0.056278
# 153401             Dissolved Oxygen     mg/l            NaN    0.124229
# 65645   Dissolved Oxygen Saturation        %            NaN    0.259567
# 64707              Dissolved Oxygen     mg/l            NaN    0.091314
# The size of the survey_data dataframe
# columns: 36
# rows   : 773
#                 LakeID           Description       Lat      Long        Town  \
# 64                BUCK  Buffer250ftWaterbody  44.46248 -72.39824    WOODBURY
# 128             CURTIS       Buffer100ftWBFL  44.38810 -72.49390      CALAIS
# 560          PENSIONER       Buffer100ftWBFL  44.87830 -72.05670  CHARLESTON
# 302  HARRIMAN (NEWBRY)        Waterbody100ft  44.10304 -72.07947     NEWBURY
# 576             PINNEO  Buffer250ftWaterbody  43.65170 -72.43140    HARTFORD
#
#       Shape_Length    Shape_Area  TREE_CANOPY_acres  GRASS_SHRUBS_acres  \
# 64     4418.648756  1.583866e+05          35.611599            2.702711
# 128   13923.088631  2.749758e+05          42.843930           18.874374
# 560  825589.912308  2.623225e+07        4538.421303         1136.946167
# 302    3322.682479  4.893726e+04           2.974032            8.071314
# 576    4116.583197  1.021722e+05           4.897498           16.967527
#
#      BARE_SOIL_acres  WATER_acres  BUILDINGS_acres  ROADS_acres  \
# 64          0.108170     0.703446         0.000000     0.000000
# 128         0.312402     2.398772         0.666133     1.648870
# 560         8.791316   724.852432         4.896200    33.955995
# 302         0.018162     0.798520         0.009946     0.198672
# 576         1.102088     0.088525         0.210225     0.166240
#
#      OTHER_PAVED_acres  RAILROADS_acres  Ag_Hay_acres  Ag_Crops_acres  \
# 64            0.008278         0.000000      0.000000        0.000000
# 128           1.196482         0.000000      3.973191        0.000000
# 560          29.270761         4.101634    332.731141       16.094631
# 302           0.020324         0.000000      0.000000        0.000000
# 576           1.813318         0.000000      0.000000        0.000000
#
#      Ag_Pasture_acres  Ag_Total_acres  Imp_Bare_Soil_acres  \
# 64                0.0        0.000000             0.114316
# 128               0.0        3.973191             0.328933
# 560               0.0      348.825771            10.833432
# 302               0.0        0.000000             0.017592
# 576               0.0        0.000000             1.140740
#
#      Imp_Buildings_acres  Imp_Other_Paved_acres  Imp_Road_acres  \
# 64              0.000000               0.016340        0.000000
# 128             0.920570               1.382622        2.810414
# 560             5.125612              32.269959       39.419253
# 302             0.009730               0.019439        0.283864
# 576             0.210968               1.971112        0.178825
#
#      Imp_Railroad_acres  Imp_Total_acres  Shrub_Shrubs_acres  \
# 64             0.000000         0.130655            0.509824
# 128            0.000000         5.442538            2.828668
# 560            4.152762        91.801019          249.367307
# 302            0.000000         0.330625            2.301596
# 576            0.000000         3.501646            0.000000
#
#      Shrub_Total_acres  TC_Coniferous_acres  TC_Deciduous_acres  \
# 64            0.509824             3.903034           31.739491
# 128           2.828668            17.191755           25.965868
# 560         249.367307          1510.073595         3036.427540
# 302           2.301596             2.015788            0.978861
# 576           0.000000             1.547716            3.393753
#
#      TC_Total_acres  Wet_Emergent_acres  Wet_Forested_acres  \
# 64        35.642525            1.046024            8.486563
# 128       43.157623            5.339568            9.322313
# 560     4546.501135          560.530688         1441.884054
# 302        2.994649            8.653627            1.454506
# 576        4.941469            0.151080            0.000000
#
#      Wet_Scrub_Shrub_acres  Wet_Total_acres                from_file  \
# 64                0.073158         9.605745            AOIs_BUCK.xls
# 128               2.967047        17.628928          AOIs_CURTIS.xls
# 560             290.080561      2292.495303      AOIs_PENSIONER.xlsx
# 302               0.000000        10.108133  AOIs_HARRIMANNEWBRY.xls
# 576               0.000000         0.151080         AOIs_PINNEO.xlsx
#
#      2016_population
# 64             886.0
# 128           1596.0
# 560            996.0
# 302           2175.0
# 576           9671.0
# The size of the health_metric dataframe
# columns: 2
# rows   : 90
#             Lake  Health_Score
# 86  SOUTH (EDEN)      2.125465
# 24       NICHOLS      1.725785
# 16       FAIRLEE      1.147697
# 21     PENSIONER      5.267679
# 5      EAST LONG      1.161514

# %% [markdown]
# ### Section 2: Merging the Data for Heatmap Visulaization

# %%
# for this visulaization we need the chem_data from 2013 - 2016 and the LakeID to merge on, the 'CharacteristicID,
# CharacteristicName, and the Result
chem_data_to_merge = chem_data[((chem_data['year'] <= 2016) & (chem_data['year'] >= 2013))].drop('population', axis=1)
chem_data_to_merge = chem_data_to_merge[['LakeID', 'CharacteristicID', 'CharacteristicName', 'Result']].copy()

# Now we Groupby LakeID as we want one measurement: the mean result of each measurement type per lake.
chem_data_to_merge = chem_data_to_merge.groupby(['LakeID', 'CharacteristicID', 'CharacteristicName']).mean().reset_index()
chem_data_to_merge.sample(10)
# Out:
#                 LakeID CharacteristicID          CharacteristicName     Result
# 1480              HOWE               PH                          pH   5.978718
# 2249            MIRROR        TOTALHARD              Total Hardness  69.623000
# 3011           SADAWGA               TN              Total Nitrogen   0.194000
# 3913  VERNON HATCHERY;        TOTALHARD              Total Hardness  19.599000
# 395             BURBEE             DNO3  Dissolved Nitrate Nitrogen   0.030000
# 2861            RESCUE              TNA                Total Sodium   4.328000
# 2015     LONG (SHEFLD)            TEMPC                 Temperature   8.826538
# 2547           NICHOLS           SECCHI         Secchi transparency   7.330952
# 2116             LOWER               DO            Dissolved Oxygen  12.563333
# 1164          GRIFFITH               PH                          pH   5.630000

# %%
# Combine the subcategories in the description
cols_from_survey = ['LakeID', 'Description', 'TREE_CANOPY_acres', 'GRASS_SHRUBS_acres', 'BARE_SOIL_acres', 'WATER_acres', 
                    'BUILDINGS_acres','ROADS_acres', 'OTHER_PAVED_acres', 'RAILROADS_acres', 'Ag_Hay_acres', 
                    'Ag_Crops_acres', 'Ag_Pasture_acres', 'Ag_Total_acres', 'Imp_Bare_Soil_acres', 
                    'Imp_Buildings_acres', 'Imp_Other_Paved_acres', 'Imp_Road_acres', 'Imp_Railroad_acres', 
                    'Imp_Total_acres', 'Shrub_Shrubs_acres', 'Shrub_Total_acres', 'TC_Coniferous_acres', 
                    'TC_Deciduous_acres', 'TC_Total_acres', 'Wet_Emergent_acres', 'Wet_Forested_acres', 
                    'Wet_Scrub_Shrub_acres', 'Wet_Total_acres']
# survey_data_grouped = survey_data[cols_from_survey].groupby('LakeID').sum().reset_index()
survey_data_grouped = survey_data[cols_from_survey]
survey_data_grouped.sample(10)
# Out:
#               LakeID           Description  TREE_CANOPY_acres  \
# 168    ECHO (HUBDTN)       Buffer100ftWBFL          28.700813
# 759         WOODWARD         Flowline100ft         100.124907
# 713           TILDYS         Flowline100ft          35.014470
# 568           PIGEON         Flowline100ft          39.289448
# 196          EMERALD         Flowline100ft         221.626621
# 174    ECHO (PLYMTH)  Buffer250ftWaterbody          54.520753
# 635  SHADOW (GLOVER)       Buffer100ftWBFL         189.336114
# 358    JOES (DANVLL)         Flowline100ft        1095.550458
# 436           LOWELL  Buffer250ftWaterbody          66.819045
# 772       ZACK WOODS  Buffer250ftWaterbody          23.058109
#
#      GRASS_SHRUBS_acres  BARE_SOIL_acres  WATER_acres  BUILDINGS_acres  \
# 168            7.661305         0.010008     2.520656         0.108664
# 759            3.815857         0.032865     2.528440         0.097730
# 713           22.785552         0.055722     2.101196         0.157097
# 568            1.920624         0.000000     0.376897         0.000000
# 196           46.810521         0.230981     9.689728         0.806798
# 174           14.658639         0.662056     1.156884         1.525812
# 635           48.181336         1.107463    23.670620         2.070122
# 358          309.273900         0.758489   125.002080         1.144776
# 436           12.125813         0.000000     1.545148         0.059799
# 772            0.155244         0.000000     0.344032         0.000000
#
#      ROADS_acres  OTHER_PAVED_acres  RAILROADS_acres  Ag_Hay_acres  \
# 168     0.000000           0.109220         0.000000      0.001483
# 759     0.369546           0.173159         0.000000      0.395736
# 713     1.413997           0.249267         0.000000      0.000000
# 568     0.000000           0.000000         0.000000      0.000000
# 196     1.157007           3.513957         1.434074     16.655500
# 174     3.101538           2.609367         0.000000      0.000000
# 635     2.627591           3.278589         0.000000     13.885572
# 358     8.122032           4.485574         0.000000     61.589683
# 436     0.000000           0.094827         0.000000      0.000000
# 772     0.000000           0.000000         0.000000      0.000000
#
#      Ag_Crops_acres  Ag_Pasture_acres  Ag_Total_acres  Imp_Bare_Soil_acres  \
# 168        0.000000          0.000000        0.001483             0.017103
# 759        0.000000          0.000000        0.395736             0.044161
# 713        2.019763          0.000000        2.019763             0.090528
# 568        0.000000          0.000000        0.000000             0.015968
# 196        0.000000          0.532329       17.187830             0.280035
# 174        0.000000          0.000000        0.000000             0.720627
# 635        1.352652          0.379971       15.618195             1.288115
# 358        0.000000          0.050623       61.640306             1.180909
# 436        0.000000          0.000000        0.000000             0.000000
# 772        0.000000          0.000000        0.000000             0.000000
#
#      Imp_Buildings_acres  Imp_Other_Paved_acres  Imp_Road_acres  \
# 168             0.107591               0.114083        0.000000
# 759             0.118647               0.175845        0.571775
# 713             0.166810               0.247956        1.466869
# 568             0.000000               0.000000        0.000000
# 196             0.841594               3.718856        3.332171
# 174             1.695815               3.074184        3.799134
# 635             2.376530               3.822608        3.968646
# 358             1.155360               4.858260        9.527255
# 436             0.078729               0.168552        0.000000
# 772             0.000000               0.000000        0.112898
#
#      Imp_Railroad_acres  Imp_Total_acres  Shrub_Shrubs_acres  \
# 168            0.000000         0.238777            2.077317
# 759            0.000000         0.910428            1.804519
# 713            0.000000         1.972164            0.000000
# 568            0.000000         0.015968            0.000000
# 196            1.578606         9.751262            1.133712
# 174            0.000000         9.289760            0.000000
# 635            0.000000        11.455899           10.604390
# 358            0.000000        16.721784           48.280976
# 436            0.000000         0.247281            2.097111
# 772            0.000000         0.112898            0.000000
#
#      Shrub_Total_acres  TC_Coniferous_acres  TC_Deciduous_acres  \
# 168           2.077317            10.981979           17.811814
# 759           1.804519            15.455304           84.699492
# 713           0.000000            20.180046           14.945042
# 568           0.000000            13.934701           25.377019
# 196           1.133712            26.044405          195.936018
# 174           0.000000            11.925863           42.715266
# 635          10.604390            99.146470           90.532777
# 358          48.280976           605.661408          492.399040
# 436           2.097111            48.545801           18.320179
# 772           0.000000            17.155167            5.910696
#
#      TC_Total_acres  Wet_Emergent_acres  Wet_Forested_acres  \
# 168       28.793793            2.469032            6.558501
# 759      100.154796            0.000000            3.786434
# 713       35.125088           21.394135            6.086230
# 568       39.311719            1.870029           13.682845
# 196      221.980422           37.619947            5.925213
# 174       54.641128            0.109794            7.590782
# 635      189.679246           13.897248           75.374860
# 358     1098.060449          158.097182          519.546762
# 436       66.865980           10.587505            6.587958
# 772       23.065863            0.000000            0.322526
#
#      Wet_Scrub_Shrub_acres  Wet_Total_acres
# 168               0.346414         9.373947
# 759               1.762558         5.548992
# 713               0.000000        27.480365
# 568               0.143692        15.696566
# 196               1.259249        44.804410
# 174               2.555944        10.256520
# 635              11.177990       100.450098
# 358              90.386579       768.030523
# 436               0.179742        17.355204
# 772               0.000000         0.322526

# %%
merged_data = survey_data_grouped.merge(chem_data_to_merge, how='inner', on='LakeID').drop('LakeID', axis=1)
print(merged_data.shape)
# Out:
# (6950, 31)

# %% [markdown]
# ### Section 3: Calculating the Correlations for Heatmap Visulaization

# %%
MEASUREMENT_THREASHOLD = 20
corrs = {}
for desc in merged_data['Description'].unique():
    corr_df = pd.DataFrame(index=merged_data.columns[:-3])
    for char in merged_data['CharacteristicID'].unique():
        df = merged_data[((merged_data['CharacteristicID'] == char) & (merged_data['Description'] == desc))]
        # because we are calculating correlations if there are measuremetns with less than 5 measurements
        #  we will drop them as the correlation wont make sense or will be misleading
        if df.shape[0] < MEASUREMENT_THREASHOLD:
            continue
        else:
            df = df.corr()
            df.drop('Result', axis=0, inplace=True)
            df.rename(columns={'Result': char}, inplace=True)
            corr_df[char] = df[char]

    # replace all nan values with 0
    corr_df.fillna(0, inplace=True)
    # drop a column if the entire column is 0
    for col in corr_df.columns:
        if corr_df[col].sum() == 0:
            corr_df.drop(col, axis=1, inplace=True)
    corr_df.drop('Description', axis=0, inplace=True)
    corr_df = corr_df.reset_index().rename(columns={'index': 'survey_type'})
    
    corrs[desc] = corr_df

# %%
for key, cor in corrs.items():
    cor['Description'] = key
    print(key)
    print(cor.shape)
# Out:
# Watershed
# (27, 23)
# Flowline100ft
# (27, 23)
# Waterbody100ft
# (27, 23)
# Buffer100ftWBFL
# (27, 23)
# Buffer250ftWaterbody
# (27, 23)

# %%
corrs_final = pd.concat(corrs, axis=0, ignore_index=True)
print(corrs_final.shape)
# Out:
# (135, 23)

# %%
# melt the data for visualization
corr_df_for_vis = pd.melt(corrs_final, id_vars=['survey_type', 'Description'], var_name='CharacteristicID', value_name='correlation')
# merge CharacteristicName
corr_df_for_vis = corr_df_for_vis.merge(merged_data[['CharacteristicID', 'CharacteristicName']].drop_duplicates(), how='left', on='CharacteristicID')
# lets take the abs value of the corelation column so that we can compare them
# corr_df_for_vis['correlation'] = np.abs(corr_df_for_vis['correlation'])
print(corr_df.shape)
corr_df_for_vis.sample(5)
# Out:
# (27, 23)
#                 survey_type           Description CharacteristicID  \
# 2107     GRASS_SHRUBS_acres       Buffer100ftWBFL               TK
# 2437        RAILROADS_acres             Watershed               TN
# 227          Ag_Total_acres       Buffer100ftWBFL           SECCHI
# 163      GRASS_SHRUBS_acres         Flowline100ft           SECCHI
# 538   Wet_Scrub_Shrub_acres  Buffer250ftWaterbody             COND
#
#       correlation   CharacteristicName
# 2107     0.091583      Total Potassium
# 2437    -0.096510       Total Nitrogen
# 227     -0.088248  Secchi transparency
# 163     -0.091669  Secchi transparency
# 538      0.055610         Conductivity

# %% [markdown]
# ### Section 4: Heatmap Visualization

# %%
options = ['Watershed', 'Buffer100ftWBFL', 'Buffer250ftWaterbody']
desc_dropdown = alt.binding_select(options=options, name='Description ')
desc_condition = alt.selection_single(fields=['Description'], init={'Description': options[0]}, bind=desc_dropdown)

chart = alt.Chart(corr_df_for_vis).mark_rect().encode(
    x=alt.X('survey_type:N', axis=alt.Axis(title=None)),
    y=alt.Y('CharacteristicName:N', axis=alt.Axis(title=None)),
    color=alt.condition(alt.datum.correlation == 0, alt.value('white'), alt.Color('correlation:Q')),
    tooltip=[alt.Tooltip('CharacteristicName'), alt.Tooltip('CharacteristicID'), alt.Tooltip('survey_type', title='Survey Type'), alt.Tooltip('correlation')]
).add_selection(
    desc_condition
).transform_filter(
    desc_condition
).properties(
    title=alt.TitleParams('Correlation heatmap of chemical measurements and Land use')
)
display(chart)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Section 5: Merging the Data and calculating the correlations for Health Metric Bar chart

# %%
# bar chart with health metric
survey = survey_data[cols_from_survey]
survey = survey.merge(health_metric, how='inner', left_on='LakeID', right_on='Lake').drop('Lake', axis=1)

# %%
results_df = pd.DataFrame(index=survey.columns[2 : -1])
for desc in survey['Description'].unique():
    df = survey[survey['Description'] == desc]
    corr_df = df.corr()
    corr_df.drop('Health_Score', axis=0, inplace=True)
    results_df[desc] = corr_df['Health_Score']
results_df = results_df.reset_index().rename(columns={'index': 'survey_type'})
results_df = pd.melt(results_df, id_vars='survey_type', var_name='Description', value_name='correlation')
results_df
# Out:
#                survey_type           Description  correlation
# 0        TREE_CANOPY_acres             Watershed    -0.035824
# 1       GRASS_SHRUBS_acres             Watershed     0.067897
# 2          BARE_SOIL_acres             Watershed     0.061495
# 3              WATER_acres             Watershed     0.038861
# 4          BUILDINGS_acres             Watershed     0.130100
# ..                     ...                   ...          ...
# 130         TC_Total_acres  Buffer250ftWaterbody    -0.035261
# 131     Wet_Emergent_acres  Buffer250ftWaterbody     0.381516
# 132     Wet_Forested_acres  Buffer250ftWaterbody    -0.038068
# 133  Wet_Scrub_Shrub_acres  Buffer250ftWaterbody     0.086818
# 134        Wet_Total_acres  Buffer250ftWaterbody     0.162405
#
# [135 rows x 3 columns]

# %% [markdown]
# ### Section 6: Health metric and land use survey bar chart

# %%
alt.Chart(results_df).mark_bar().encode(
    x=alt.X('correlation:Q'),
    y=alt.Y('survey_type', sort='-x')
).add_selection(
    desc_condition
).transform_filter(
    desc_condition
).properties(
    title=alt.TitleParams('Survey categories correlated with the derived Health Meric')
)
# Out:
# alt.Chart(...)
